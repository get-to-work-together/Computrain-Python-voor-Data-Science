# %% [markdown]
# # Demo Pandas

# %%
import pandas as pd

# %%
filename = '../datasets/ca-500.csv'

# filename = 'https://raw.githubusercontent.com/get-to-work-together/Computrain-Python-voor-Data-Science/refs/heads/main/datasets/ca-500.csv'

df = pd.read_csv(filename, sep=',')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_json('ca_500.json', orient='index', index=True)

# %%
df.to_excel('ca_500.xlsx')

# %%
df = df.drop(4)

# %%
df.value_counts('province').plot(kind='barh')
# Out:
# <Axes: ylabel='province'>

# %%
url = 'https://nl.wikipedia.org/wiki/Provincies_van_Nederland'

df = pd.read_html(url, thousands='.', decimal=',')[0]
df
# Out:
#     Vlag            Provincie  Bevolking[1]  Oppervlakte (land+water) in km²  \
# 0    NaN            Groningen        596163                          2959.68
# 1    NaN  Fryslân (Friesland)        659612                          5748.77
# 2    NaN              Drenthe        502120                          2680.39
# 3    NaN           Overijssel       1184551                          3420.74
# 4    NaN            Flevoland        444850                          2412.31
# 5    NaN           Gelderland       2133751                          5136.31
# 6    NaN              Utrecht       1387657                          1560.05
# 7    NaN        Noord-Holland       2956223                          4091.93
# 8    NaN         Zuid-Holland       3804737                          3307.86
# 9    NaN              Zeeland        391142                          2933.44
# 10   NaN        Noord-Brabant       2626368                          5082.06
# ...

# %%
df.sort_values('inw./km²[2]', ascending=False)
# Out:
#     Vlag            Provincie  Bevolking[1]  Oppervlakte (land+water) in km²  \
# 8    NaN         Zuid-Holland       3804737                          3307.86
# 7    NaN        Noord-Holland       2956223                          4091.93
# 6    NaN              Utrecht       1387657                          1560.05
# 10   NaN        Noord-Brabant       2626368                          5082.06
# 11   NaN              Limburg       1128334                          2209.85
# 5    NaN           Gelderland       2133751                          5136.31
# 3    NaN           Overijssel       1184551                          3420.74
# 4    NaN            Flevoland        444850                          2412.31
# 0    NaN            Groningen        596163                          2959.68
# 9    NaN              Zeeland        391142                          2933.44
# 1    NaN  Fryslân (Friesland)        659612                          5748.77
# ...

# %%
df = df.rename(columns={
    'Bevolking[1]': 'Bevolking',
    'Oppervlakte (land+water) in km²': 'Oppervlakte',
    'Oppervlakte (land) in km²': 'Oppervlakte Land',
    'inw./km²[2]': 'Dichtheid'
})

# %%
df
# Out:
#     Vlag            Provincie  Bevolking  Oppervlakte  Oppervlakte Land  \
# 0    NaN            Groningen     596163      2959.68           2323.94
# 1    NaN  Fryslân (Friesland)     659612      5748.77           3335.62
# 2    NaN              Drenthe     502120      2680.39           2632.65
# 3    NaN           Overijssel    1184551      3420.74           3319.00
# 4    NaN            Flevoland     444850      2412.31           1411.63
# 5    NaN           Gelderland    2133751      5136.31           4963.71
# 6    NaN              Utrecht    1387657      1560.05           1485.46
# 7    NaN        Noord-Holland    2956223      4091.93           2664.82
# 8    NaN         Zuid-Holland    3804737      3307.86           2700.07
# 9    NaN              Zeeland     391142      2933.44           1782.12
# 10   NaN        Noord-Brabant    2626368      5082.06           4905.46
# 11   NaN              Limburg    1128334      2209.85           2146.61
#
# ...

# %%
df['Bevolking'].sum()
# Out:
# 17815508

# %%
df['Berekende Dichtheid'] = (df['Bevolking'] / df['Oppervlakte Land']).round().astype('int')
# Out:
# 0      257
# 1      198
# 2      191
# 3      357
# 4      315
# 5      430
# 6      934
# 7     1109
# 8     1409
# 9      219
# 10     535
# 11     526
# dtype: int32

# %%
df
# Out:
#     Vlag            Provincie  Bevolking  Oppervlakte  Oppervlakte Land  \
# 0    NaN            Groningen     596163      2959.68           2323.94
# 1    NaN  Fryslân (Friesland)     659612      5748.77           3335.62
# 2    NaN              Drenthe     502120      2680.39           2632.65
# 3    NaN           Overijssel    1184551      3420.74           3319.00
# 4    NaN            Flevoland     444850      2412.31           1411.63
# 5    NaN           Gelderland    2133751      5136.31           4963.71
# 6    NaN              Utrecht    1387657      1560.05           1485.46
# 7    NaN        Noord-Holland    2956223      4091.93           2664.82
# 8    NaN         Zuid-Holland    3804737      3307.86           2700.07
# 9    NaN              Zeeland     391142      2933.44           1782.12
# 10   NaN        Noord-Brabant    2626368      5082.06           4905.46
# 11   NaN              Limburg    1128334      2209.85           2146.61
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Vlag                             0 non-null      float64
#  1   Provincie                        12 non-null     object
#  2   Bevolking                        12 non-null     int64
#  3   Oppervlakte                      12 non-null     float64
#  4   Oppervlakte Land                 12 non-null     float64
#  5   Dichtheid                        12 non-null     int64
#  6   Hoofdstad                        12 non-null     object
#  7   Gemeente met de meeste inwoners  12 non-null     object
#  8   Berekende Dichtheid              12 non-null     int32
# dtypes: float64(3), int32(1), int64(2), object(3)
# memory usage: 944.0+ bytes

# %%
df['Provincie'].str.upper().str.slice(0, 2)
# Out:
# 0     GR
# 1     FR
# 2     DR
# 3     OV
# 4     FL
# 5     GE
# 6     UT
# 7     NO
# 8     ZU
# 9     ZE
# 10    NO
# 11    LI
# Name: Provincie, dtype: object

# %%
df
# Out:
#     Vlag            Provincie  Bevolking  Oppervlakte  Oppervlakte Land  \
# 0    NaN            Groningen     596163      2959.68           2323.94
# 1    NaN  Fryslân (Friesland)     659612      5748.77           3335.62
# 2    NaN              Drenthe     502120      2680.39           2632.65
# 3    NaN           Overijssel    1184551      3420.74           3319.00
# 4    NaN            Flevoland     444850      2412.31           1411.63
# 5    NaN           Gelderland    2133751      5136.31           4963.71
# 6    NaN              Utrecht    1387657      1560.05           1485.46
# 7    NaN        Noord-Holland    2956223      4091.93           2664.82
# 8    NaN         Zuid-Holland    3804737      3307.86           2700.07
# 9    NaN              Zeeland     391142      2933.44           1782.12
# 10   NaN        Noord-Brabant    2626368      5082.06           4905.46
# 11   NaN              Limburg    1128334      2209.85           2146.61
#
# ...

# %%
df[ ['Provincie','Hoofdstad','Gemeente met de meeste inwoners'] ]
# Out:
#               Provincie         Hoofdstad Gemeente met de meeste inwoners
# 0             Groningen         Groningen                       Groningen
# 1   Fryslân (Friesland)        Leeuwarden                      Leeuwarden
# 2               Drenthe             Assen                           Emmen
# 3            Overijssel            Zwolle                        Enschede
# 4             Flevoland          Lelystad                          Almere
# 5            Gelderland            Arnhem                        Nijmegen
# 6               Utrecht           Utrecht                         Utrecht
# 7         Noord-Holland           Haarlem                       Amsterdam
# 8          Zuid-Holland          Den Haag                       Rotterdam
# 9               Zeeland        Middelburg                       Terneuzen
# 10        Noord-Brabant  's-Hertogenbosch                       Eindhoven
# 11              Limburg        Maastricht                      Maastricht

# %%
df[ df['Bevolking'] > 1000000 ]
# Out:
#     Vlag      Provincie  Bevolking  Oppervlakte  Oppervlakte Land  Dichtheid  \
# 3    NaN     Overijssel    1184551      3420.74           3319.00        357
# 5    NaN     Gelderland    2133751      5136.31           4963.71        430
# 6    NaN        Utrecht    1387657      1560.05           1485.46        934
# 7    NaN  Noord-Holland    2956223      4091.93           2664.82       1109
# 8    NaN   Zuid-Holland    3804737      3307.86           2700.07       1409
# 10   NaN  Noord-Brabant    2626368      5082.06           4905.46        535
# 11   NaN        Limburg    1128334      2209.85           2146.61        526
#
#            Hoofdstad Gemeente met de meeste inwoners  Berekende Dichtheid
# 3             Zwolle                        Enschede                  357
# 5             Arnhem                        Nijmegen                  430
# 6            Utrecht                         Utrecht                  934
# ...

# %%
df.query('Bevolking > 1000000')
# Out:
#     Vlag      Provincie  Bevolking  Oppervlakte  Oppervlakte Land  Dichtheid  \
# 3    NaN     Overijssel    1184551      3420.74           3319.00        357
# 5    NaN     Gelderland    2133751      5136.31           4963.71        430
# 6    NaN        Utrecht    1387657      1560.05           1485.46        934
# 7    NaN  Noord-Holland    2956223      4091.93           2664.82       1109
# 8    NaN   Zuid-Holland    3804737      3307.86           2700.07       1409
# 10   NaN  Noord-Brabant    2626368      5082.06           4905.46        535
# 11   NaN        Limburg    1128334      2209.85           2146.61        526
#
#            Hoofdstad Gemeente met de meeste inwoners  Berekende Dichtheid
# 3             Zwolle                        Enschede                  357
# 5             Arnhem                        Nijmegen                  430
# 6            Utrecht                         Utrecht                  934
# ...

# %%
df = df.drop('Vlag', axis='columns')

# %%
df
# Out:
#               Provincie  Bevolking  Oppervlakte  Oppervlakte Land  Dichtheid  \
# 0             Groningen     596163      2959.68           2323.94        257
# 1   Fryslân (Friesland)     659612      5748.77           3335.62        198
# 2               Drenthe     502120      2680.39           2632.65        191
# 3            Overijssel    1184551      3420.74           3319.00        357
# 4             Flevoland     444850      2412.31           1411.63        315
# 5            Gelderland    2133751      5136.31           4963.71        430
# 6               Utrecht    1387657      1560.05           1485.46        934
# 7         Noord-Holland    2956223      4091.93           2664.82       1109
# 8          Zuid-Holland    3804737      3307.86           2700.07       1409
# 9               Zeeland     391142      2933.44           1782.12        219
# 10        Noord-Brabant    2626368      5082.06           4905.46        535
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Provincie                        12 non-null     object
#  1   Bevolking                        12 non-null     int64
#  2   Oppervlakte                      12 non-null     float64
#  3   Oppervlakte Land                 12 non-null     float64
#  4   Dichtheid                        12 non-null     int64
#  5   Hoofdstad                        12 non-null     object
#  6   Gemeente met de meeste inwoners  12 non-null     object
#  7   Berekende Dichtheid              12 non-null     int32
# dtypes: float64(2), int32(1), int64(2), object(3)
# memory usage: 848.0+ bytes

# %%
df.dtypes
# Out:
# Provincie                           object
# Bevolking                            int64
# Oppervlakte                        float64
# Oppervlakte Land                   float64
# Dichtheid                            int64
# Hoofdstad                           object
# Gemeente met de meeste inwoners     object
# Berekende Dichtheid                  int32
# dtype: object

# %%
df.head(3)
# Out:
#              Provincie  Bevolking  Oppervlakte  Oppervlakte Land  Dichtheid  \
# 0            Groningen     596163      2959.68           2323.94        257
# 1  Fryslân (Friesland)     659612      5748.77           3335.62        198
# 2              Drenthe     502120      2680.39           2632.65        191
#
#     Hoofdstad Gemeente met de meeste inwoners  Berekende Dichtheid
# 0   Groningen                       Groningen                  257
# 1  Leeuwarden                      Leeuwarden                  198
# 2       Assen                           Emmen                  191

# %%
df.tail(3)
# Out:
#         Provincie  Bevolking  Oppervlakte  Oppervlakte Land  Dichtheid  \
# 9         Zeeland     391142      2933.44           1782.12        219
# 10  Noord-Brabant    2626368      5082.06           4905.46        535
# 11        Limburg    1128334      2209.85           2146.61        526
#
#            Hoofdstad Gemeente met de meeste inwoners  Berekende Dichtheid
# 9         Middelburg                       Terneuzen                  219
# 10  's-Hertogenbosch                       Eindhoven                  535
# 11        Maastricht                      Maastricht                  526

# %%
df.describe()
# Out:
#           Bevolking  Oppervlakte  Oppervlakte Land    Dichtheid  \
# count  1.200000e+01    12.000000         12.000000    12.000000
# mean   1.484626e+06  3461.949167       2805.924167   540.000000
# std    1.136662e+06  1297.173728       1170.544359   399.145451
# min    3.911420e+05  1560.050000       1411.630000   191.000000
# 25%    5.726522e+05  2613.370000       2055.487500   247.500000
# 50%    1.156442e+06  3133.770000       2648.735000   393.500000
# 75%    2.256905e+06  4339.462500       3323.155000   634.750000
# max    3.804737e+06  5748.770000       4963.710000  1409.000000
#
#        Berekende Dichtheid
# count            12.000000
# mean            540.000000
# std             399.145451
# min             191.000000
# 25%             247.500000
# 50%             393.500000
# 75%             634.750000
# max            1409.000000

# %%
df.count()
# Out:
# Provincie                          12
# Bevolking                          12
# Oppervlakte                        12
# Oppervlakte Land                   12
# Dichtheid                          12
# Hoofdstad                          12
# Gemeente met de meeste inwoners    12
# Berekende Dichtheid                12
# dtype: int64

# %%
df.value_counts('Provincie')
# Out:
# Provincie
# Drenthe                1
# Flevoland              1
# Fryslân (Friesland)    1
# Gelderland             1
# Groningen              1
# Limburg                1
# Noord-Brabant          1
# Noord-Holland          1
# Overijssel             1
# Utrecht                1
# Zeeland                1
# Zuid-Holland           1
# dtype: int64
