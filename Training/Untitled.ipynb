# %% [markdown]
# # Opdraht 5 - World Bank Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename = '../datasets/World Bank DataBank World Development Indicators/indicators.csv'

# %%
df = pd.read_csv(filename, encoding='cp1252')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1524 entries, 0 to 1523
# Data columns (total 54 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   1521 non-null   object
#  1   Country Code   1519 non-null   object
#  2   Series Name    1519 non-null   object
#  3   Series Code    1519 non-null   object
#  4   1974 [YR1974]  1519 non-null   object
#  5   1975 [YR1975]  1519 non-null   object
#  6   1976 [YR1976]  1519 non-null   object
#  7   1977 [YR1977]  1519 non-null   object
#  8   1978 [YR1978]  1519 non-null   object
#  9   1979 [YR1979]  1519 non-null   object
#  10  1980 [YR1980]  1519 non-null   object
#  11  1981 [YR1981]  1519 non-null   object
#  12  1982 [YR1982]  1519 non-null   object
#  13  1983 [YR1983]  1519 non-null   object
#  14  1984 [YR1984]  1519 non-null   object
#  15  1985 [YR1985]  1519 non-null   object
#  16  1986 [YR1986]  1519 non-null   object
#  17  1987 [YR1987]  1519 non-null   object
#  18  1988 [YR1988]  1519 non-null   object
#  19  1989 [YR1989]  1519 non-null   object
#  20  1990 [YR1990]  1519 non-null   object
#  21  1991 [YR1991]  1519 non-null   object
#  22  1992 [YR1992]  1519 non-null   object
#  23  1993 [YR1993]  1519 non-null   object
#  24  1994 [YR1994]  1519 non-null   object
#  25  1995 [YR1995]  1519 non-null   object
#  26  1996 [YR1996]  1519 non-null   object
#  27  1997 [YR1997]  1519 non-null   object
#  28  1998 [YR1998]  1519 non-null   object
#  29  1999 [YR1999]  1519 non-null   object
#  30  2000 [YR2000]  1519 non-null   object
#  31  2001 [YR2001]  1519 non-null   object
#  32  2002 [YR2002]  1519 non-null   object
#  33  2003 [YR2003]  1519 non-null   object
#  34  2004 [YR2004]  1519 non-null   object
#  35  2005 [YR2005]  1519 non-null   object
#  36  2006 [YR2006]  1519 non-null   object
#  37  2007 [YR2007]  1519 non-null   object
#  38  2008 [YR2008]  1519 non-null   object
#  39  2009 [YR2009]  1519 non-null   object
#  40  2010 [YR2010]  1519 non-null   object
#  41  2011 [YR2011]  1519 non-null   object
#  42  2012 [YR2012]  1519 non-null   object
#  43  2013 [YR2013]  1519 non-null   object
#  44  2014 [YR2014]  1519 non-null   object
#  45  2015 [YR2015]  1519 non-null   object
#  46  2016 [YR2016]  1519 non-null   object
#  47  2017 [YR2017]  1519 non-null   object
#  48  2018 [YR2018]  1519 non-null   object
#  49  2019 [YR2019]  1519 non-null   object
#  50  2020 [YR2020]  1519 non-null   object
#  51  2021 [YR2021]  1519 non-null   object
#  52  2022 [YR2022]  1519 non-null   object
#  53  2023 [YR2023]  1519 non-null   object
# dtypes: object(54)
# memory usage: 643.1+ KB

# %%
df[df['Country Code']=='NLD']
# Out:
#     Country Name Country Code  \
# 973  Netherlands          NLD
# 974  Netherlands          NLD
# 975  Netherlands          NLD
# 976  Netherlands          NLD
# 977  Netherlands          NLD
# 978  Netherlands          NLD
# 979  Netherlands          NLD
#
#                                            Series Name        Series Code  \
# 973                                  GDP (current US$)     NY.GDP.MKTP.CD
# 974                                  Population, total        SP.POP.TOTL
# 975            Life expectancy at birth, total (years)     SP.DYN.LE00.IN
# 976  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 977              Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS
# 978  GDP per capita, PPP (constant 2021 internation...  NY.GDP.PCAP.PP.KD
# 979           Fertility rate, total (births per woman)     SP.DYN.TFRT.IN
#
#         1974 [YR1974]     1975 [YR1975]     1976 [YR1976]     1977 [YR1977]  \
# 973  87243413394.5405  100249523353.085  109168720620.103  127016990212.804
# 974          13545056          13666335          13774037          13856185
# 975  74.5368292682927  74.4987804878049  74.6470731707317  75.2214634146342
# 976                ..                ..                ..                ..
# 977                ..                ..                ..                ..
# 978                ..                ..                ..                ..
# 979              1.77              1.66              1.63              1.58
#
#         1978 [YR1978]     1979 [YR1979]  ...     2014 [YR2014]  \
# 973  155859695457.323  179669405690.432  ...  892167986713.722
# 974          13941700          14038270  ...          16865008
# 975  75.1451219512195  75.6060975609756  ...  81.7073170731707
# 976                ..                ..  ...              5602
# 977                ..                ..  ...             10.57
# 978                ..                ..  ...  61615.5860911043
# 979              1.58              1.56  ...              1.71
#
#         2015 [YR2015]     2016 [YR2016]     2017 [YR2017]     2018 [YR2018]  \
# 973  765572770634.375   784060430240.08   833869641687.06  914043438179.607
# 974          16939923          17030314          17131296          17231624
# 975   81.509756097561  81.5609756097561  81.7609756097561  81.8121951219512
# 976              4677              4644              4935              5331
# 977             10.32             10.06             10.11             10.02
# 978  62544.9131401361  63576.4761161142  65041.4591487786  66189.4000984502
# 979              1.66              1.66              1.62              1.59
#
#         2019 [YR2019]     2020 [YR2020]     2021 [YR2021]     2022 [YR2022]  \
# 973  910194347568.626  909793466661.481  1029678338329.44  1009398719033.08
# 974          17344874          17441500          17533044          17700982
# 975  82.1121951219512  81.3585365853659   81.309756097561  81.7146341463415
# 976              5341              5858              6539                ..
# 977             10.14             11.21             11.29                ..
# 978  67043.1699696165  64080.8302893499  67693.3264311302  69953.6730068751
# 979              1.57              1.54              1.62             1.487
#
#     2023 [YR2023]
# 973            ..
# 974            ..
# 975            ..
# 976            ..
# 977            ..
# 978            ..
# 979            ..
#
# [7 rows x 54 columns]

# %%
df_selected = df[df['Series Code'].isin(['SP.POP.TOTL', 'SP.DYN.LE00.IN', 'NY.GDP.PCAP.PP.KD'])].copy()

# %%
df_selected[['Country Name', 'Country Code']].value_counts()
# Out:
# Country Name   Country Code
# Afghanistan    AFG             3
# Pakistan       PAK             3
# Nepal          NPL             3
# Netherlands    NLD             3
# New Caledonia  NCL             3
#                               ..
# Greece         GRC             3
# Greenland      GRL             3
# Grenada        GRD             3
# Guam           GUM             3
# Zimbabwe       ZWE             3
# Length: 217, dtype: int64

# %%
df_selected[['Series Name', 'Series Code']].value_counts()
# Out:
# Series Name                                          Series Code
# GDP per capita, PPP (constant 2021 international $)  NY.GDP.PCAP.PP.KD    217
# Life expectancy at birth, total (years)              SP.DYN.LE00.IN       217
# Population, total                                    SP.POP.TOTL          217
# dtype: int64

# %%
df_melted = df_selected.melt(id_vars=['Country Name', 'Country Code', 'Series Name', 'Series Code'], 
                             value_vars=list(df_selected.columns)[4:], 
                             var_name='Year')

df_melted
# Out:
#       Country Name Country Code  \
# 0      Afghanistan          AFG
# 1      Afghanistan          AFG
# 2      Afghanistan          AFG
# 3          Albania          ALB
# 4          Albania          ALB
# ...            ...          ...
# 32545       Zambia          ZMB
# 32546       Zambia          ZMB
# 32547     Zimbabwe          ZWE
# 32548     Zimbabwe          ZWE
# 32549     Zimbabwe          ZWE
#
#                                              Series Name        Series Code  \
# 0                                      Population, total        SP.POP.TOTL
# 1                Life expectancy at birth, total (years)     SP.DYN.LE00.IN
# 2      GDP per capita, PPP (constant 2021 internation...  NY.GDP.PCAP.PP.KD
# 3                                      Population, total        SP.POP.TOTL
# 4                Life expectancy at birth, total (years)     SP.DYN.LE00.IN
# ...                                                  ...                ...
# 32545            Life expectancy at birth, total (years)     SP.DYN.LE00.IN
# 32546  GDP per capita, PPP (constant 2021 internation...  NY.GDP.PCAP.PP.KD
# 32547                                  Population, total        SP.POP.TOTL
# 32548            Life expectancy at birth, total (years)     SP.DYN.LE00.IN
# 32549  GDP per capita, PPP (constant 2021 internation...  NY.GDP.PCAP.PP.KD
#
#                 Year     value
# 0      1974 [YR1974]  11869879
# 1      1974 [YR1974]     39.55
# 2      1974 [YR1974]        ..
# 3      1974 [YR1974]   2350124
# 4      1974 [YR1974]    67.769
# ...              ...       ...
# 32545  2023 [YR2023]        ..
# 32546  2023 [YR2023]        ..
# 32547  2023 [YR2023]        ..
# 32548  2023 [YR2023]        ..
# 32549  2023 [YR2023]        ..
#
# [32550 rows x 6 columns]

# %%
df_pivot = df_melted.pivot(index=['Country Name', 'Country Code', 'Year'], 
                           columns=['Series Name'], 
                           values='value').reset_index()

df_pivot
# Out:
# Series Name Country Name Country Code           Year  \
# 0            Afghanistan          AFG  1974 [YR1974]
# 1            Afghanistan          AFG  1975 [YR1975]
# 2            Afghanistan          AFG  1976 [YR1976]
# 3            Afghanistan          AFG  1977 [YR1977]
# 4            Afghanistan          AFG  1978 [YR1978]
# ...                  ...          ...            ...
# 10845           Zimbabwe          ZWE  2019 [YR2019]
# 10846           Zimbabwe          ZWE  2020 [YR2020]
# 10847           Zimbabwe          ZWE  2021 [YR2021]
# 10848           Zimbabwe          ZWE  2022 [YR2022]
# 10849           Zimbabwe          ZWE  2023 [YR2023]
#
# Series Name GDP per capita, PPP (constant 2021 international $)  \
# 0                                                           ..
# 1                                                           ..
# 2                                                           ..
# 3                                                           ..
# 4                                                           ..
# ...                                                        ...
# 10845                                         3412.96669011384
# 10846                                         3082.91899723064
# 10847                                         3276.26775280153
# 10848                                         3420.03028009733
# 10849                                                       ..
#
# Series Name Life expectancy at birth, total (years) Population, total
# 0                                             39.55          11869879
# 1                                              40.1          12157386
# 2                                            40.645          12425267
# 3                                            41.228          12687301
# 4                                            40.271          12938862
# ...                                             ...               ...
# 10845                                        61.292          15354608
# 10846                                        61.124          15669666
# 10847                                        59.253          15993524
# 10848                                        59.391          16320537
# 10849                                            ..                ..
#
# [10850 rows x 6 columns]

# %%
df_year = df_pivot[df_pivot['Year'].str.startswith('2022')]
df_year
# Out:
# Series Name           Country Name Country Code           Year  \
# 48                     Afghanistan          AFG  2022 [YR2022]
# 98                         Albania          ALB  2022 [YR2022]
# 148                        Algeria          DZA  2022 [YR2022]
# 198                 American Samoa          ASM  2022 [YR2022]
# 248                        Andorra          AND  2022 [YR2022]
# ...                            ...          ...            ...
# 10648        Virgin Islands (U.S.)          VIR  2022 [YR2022]
# 10698           West Bank and Gaza          PSE  2022 [YR2022]
# 10748                  Yemen, Rep.          YEM  2022 [YR2022]
# 10798                       Zambia          ZMB  2022 [YR2022]
# 10848                     Zimbabwe          ZWE  2022 [YR2022]
#
# Series Name GDP per capita, PPP (constant 2021 international $)  \
# 48                                                          ..
# 98                                            17261.0310926058
# 148                                            13090.883957655
# 198                                                         ..
# 248                                           63378.9950967498
# ...                                                        ...
# 10648                                                       ..
# 10698                                         5744.80481674316
# 10748                                                       ..
# 10798                                         3610.66640769053
# 10848                                         3420.03028009733
#
# Series Name Life expectancy at birth, total (years) Population, total
# 48                                           62.879          41128771
# 98                                           76.833           2777689
# 148                                          77.129          44903225
# 198                                              ..             44273
# 248                                              ..             79824
# ...                                             ...               ...
# 10648                               80.319512195122            105413
# 10698                                        73.444           5043612
# 10748                                         63.72          33696614
# 10798                                        61.803          20017675
# 10848                                        59.391          16320537
#
# [217 rows x 6 columns]

# %%
plt.scatter(x=df_year['GDP per capita, PPP (constant 2021 international $)'], 
            y=df_year['Life expectancy at birth, total (years)'])
plt.show()
