# %% [markdown]
# # Opdracht 5.1 - Data preparatie

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Load the iris dataset

# %% [markdown]
# #### from a file

# %%
filename = '../datasets/iris.csv'
df = pd.read_csv(filename)

# %% [markdown]
# #### or from Seaborn

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Explore the dataset

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df['species'] = df['species'].astype('category')

# %%
df['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.plot(kind='box')
plt.show()

# %% [markdown]
# ### Plot the dataset

# %%
sns.pairplot(data=df, hue='species');

# %%
def plot_iris(df_iris, col1, col2):
    sns.lmplot(data = df_iris, 
               x = col1, 
               y = col2, 
               hue = 'species', 
               fit_reg = False)
    plt.xlabel(col1)
    plt.ylabel(col2)
    plt.title('Iris species')
    plt.show()

names = list(df['species'].unique())
from itertools import combinations
for x, y in combinations(names[:4], 2):
    plot_iris(df, x, y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 15
#      13 from itertools import combinations
#      14 for x, y in combinations(names[:4], 2):
# ---> 15     plot_iris(df, x, y)
#
# Cell In[26], line 2, in plot_iris(df_iris, col1, col2)
#       1 def plot_iris(df_iris, col1, col2):
# ----> 2     sns.lmplot(data = df_iris,
#       3                x = col1,
#       4                y = col2,
#       5                hue = 'species',
#       6                fit_reg = False)
#       7     plt.xlabel(col1)
#       8     plt.ylabel(col2)
#
# File c:\users\cursist\Anaconda3\lib\site-packages\seaborn\regression.py:595, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     593 need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     594 cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 595 data = data[cols]
#     597 # Initialize the grid
#     598 facets = FacetGrid(
#     599     data, row=row, col=col, hue=hue,
#     600     palette=palette,
#    (...)
#     603     **facet_kws,
#     604 )
#
# File c:\users\cursist\Anaconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File c:\users\cursist\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File c:\users\cursist\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['setosa', 'versicolor'] not in index"

# %%
sns.pairplot(data = df, 
             vars = df.columns[:-1], 
             hue = df.columns[-1])
plt.show()

# %% [markdown]
# ## Split in training and test set

# %%
from sklearn.model_selection import train_test_split

# %%
np.random.seed(1234)

df_train, df_test = train_test_split(df, test_size = 0.3)

print('df_train', df_train.shape)
print('df_test', df_test.shape)
# Out:
# df_train (105, 5)
# df_test (45, 5)

# %%
df_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 9             4.9          3.1           1.5          0.1      setosa
# 114           5.8          2.8           5.1          2.4   virginica
# 145           6.7          3.0           5.2          2.3   virginica
# 135           7.7          3.0           6.1          2.3   virginica
# 140           6.7          3.1           5.6          2.4   virginica
# ..            ...          ...           ...          ...         ...
# 143           6.8          3.2           5.9          2.3   virginica
# 116           6.5          3.0           5.5          1.8   virginica
# 53            5.5          2.3           4.0          1.3  versicolor
# 38            4.4          3.0           1.3          0.2      setosa
# 47            4.6          3.2           1.4          0.2      setosa
#
# [105 rows x 5 columns]

# %% [markdown]
# ## Identify features and target

# %%
feature_names = list(df.columns[:-1])
target_name = df.columns[-1]

print('features:', feature_names)
print('target:', target_name)
# Out:
# features: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
# target: species

# %% [markdown]
# #### create separate dataframes

# %%
df_train_features = df_train[feature_names]
df_train_target = df_train[target_name]
df_test_features = df_test[feature_names]
df_test_target = df_test[target_name]

print('df_train_features', df_train_features.shape)
print('df_train_target', df_train_target.shape)
print('df_test_features', df_test_features.shape)
print('df_test_target', df_test_target.shape)
# Out:
# df_train_features (105, 4)
# df_train_target (105,)
# df_test_features (45, 4)
# df_test_target (45,)

# %%
df_train_features
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 9             4.9          3.1           1.5          0.1
# 114           5.8          2.8           5.1          2.4
# 145           6.7          3.0           5.2          2.3
# 135           7.7          3.0           6.1          2.3
# 140           6.7          3.1           5.6          2.4
# ..            ...          ...           ...          ...
# 143           6.8          3.2           5.9          2.3
# 116           6.5          3.0           5.5          1.8
# 53            5.5          2.3           4.0          1.3
# 38            4.4          3.0           1.3          0.2
# 47            4.6          3.2           1.4          0.2
#
# [105 rows x 4 columns]

# %% [markdown]
# #### convert to numpy array for scikit-learn

# %%
X_train = np.array(df_train_features)
y_train = np.array(df_train_target)
X_test = np.array(df_test_features)
y_test = np.array(df_test_target)

print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('y_test', y_test.shape)
# Out:
# X_train (105, 4)
# y_train (105,)
# X_test (45, 4)
# y_test (45,)

# %% [markdown]
# ## Scale the numeric features

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
scaler = StandardScaler()

scaler.fit(df_train_features)

train_features_scaled = scaler.transform(df_train_features)
test_features_scaled = scaler.transform(df_test_features)

print('mean', round(train_features_scaled.mean(), 10))
print('std', train_features_scaled.std())

print('train_features_scaled', train_features_scaled.shape)
print('test_features_scaled', test_features_scaled.shape)
# Out:
# mean 0.0
# std 0.9999999999999999
# train_features_scaled (105, 4)
# test_features_scaled (45, 4)

# %%
scaler = MinMaxScaler()

scaler.fit(df_train_features)

train_features_scaled = scaler.transform(df_train_features)
test_features_scaled = scaler.transform(df_test_features)

print('min', train_features_scaled.min())
print('max', train_features_scaled.max())

print('train_features_scaled', train_features_scaled.shape)
print('test_features_scaled', test_features_scaled.shape)
# Out:
# min 0.0
# max 1.0
# train_features_scaled (105, 4)
# test_features_scaled (45, 4)

# %%
df_train_features_scaled = pd.DataFrame(train_features_scaled, 
                                        columns = [col + '_scaled' for col in list(df_train_features.columns)], 
                                        index = df_train_features.index)
df_train_features_scaled
# Out:
#      sepal_length_scaled  sepal_width_scaled  petal_length_scaled  \
# 9               0.166667            0.458333             0.068966
# 114             0.416667            0.333333             0.689655
# 145             0.666667            0.416667             0.706897
# 135             0.944444            0.416667             0.862069
# 140             0.666667            0.458333             0.775862
# ..                   ...                 ...                  ...
# 143             0.694444            0.500000             0.827586
# 116             0.611111            0.416667             0.758621
# 53              0.333333            0.125000             0.500000
# 38              0.027778            0.416667             0.034483
# 47              0.083333            0.500000             0.051724
#
#      petal_width_scaled
# 9              0.000000
# 114            0.958333
# 145            0.916667
# 135            0.916667
# 140            0.958333
# ..                  ...
# 143            0.916667
# 116            0.708333
# 53             0.500000
# 38             0.041667
# 47             0.041667
#
# [105 rows x 4 columns]

# %%
df_test_features_scaled = pd.DataFrame(test_features_scaled, 
                                       columns = [col + '_scaled' for col in list(df_test_features.columns)], 
                                       index = df_test_features.index)
df_test_features_scaled
# Out:
#      sepal_length_scaled  sepal_width_scaled  petal_length_scaled  \
# 91              0.500000            0.416667             0.603448
# 63              0.500000            0.375000             0.620690
# 103             0.555556            0.375000             0.775862
# 6               0.083333            0.583333             0.051724
# 59              0.250000            0.291667             0.482759
# 29              0.111111            0.500000             0.086207
# 27              0.250000            0.625000             0.068966
# 35              0.194444            0.500000             0.017241
# 99              0.388889            0.333333             0.517241
# 122             0.944444            0.333333             0.965517
# 82              0.416667            0.291667             0.482759
# 42              0.027778            0.500000             0.034483
# 117             0.944444            0.750000             0.965517
# 61              0.444444            0.416667             0.534483
# 43              0.194444            0.625000             0.086207
# 79              0.388889            0.250000             0.413793
# 100             0.555556            0.541667             0.844828
# 25              0.194444            0.416667             0.086207
# 108             0.666667            0.208333             0.810345
# 94              0.361111            0.291667             0.534483
# 74              0.583333            0.375000             0.551724
# 54              0.611111            0.333333             0.603448
# 51              0.583333            0.500000             0.586207
# 73              0.500000            0.333333             0.620690
# 109             0.805556            0.666667             0.862069
# 48              0.277778            0.708333             0.068966
# 123             0.555556            0.291667             0.655172
# 92              0.416667            0.250000             0.500000
# 102             0.777778            0.416667             0.827586
# 11              0.138889            0.583333             0.086207
# 98              0.222222            0.208333             0.327586
# 126             0.527778            0.333333             0.637931
# 40              0.194444            0.625000             0.034483
# 133             0.555556            0.333333             0.689655
# 77              0.666667            0.416667             0.672414
# 24              0.138889            0.583333             0.137931
# 8               0.027778            0.375000             0.051724
# 20              0.305556            0.583333             0.103448
# 22              0.083333            0.666667            -0.017241
# 93              0.194444            0.125000             0.379310
# 36              0.333333            0.625000             0.034483
# 68              0.527778            0.083333             0.586207
# 32              0.250000            0.875000             0.068966
# 141             0.722222            0.458333             0.689655
# 125             0.805556            0.500000             0.844828
#
#      petal_width_scaled
# 91             0.541667
# 63             0.541667
# 103            0.708333
# 6              0.083333
# 59             0.541667
# 29             0.041667
# 27             0.041667
# 35             0.041667
# 99             0.500000
# 122            0.791667
# 82             0.458333
# 42             0.041667
# 117            0.875000
# 61             0.583333
# 43             0.208333
# 79             0.375000
# 100            1.000000
# 25             0.041667
# 108            0.708333
# 94             0.500000
# 74             0.500000
# 54             0.583333
# 51             0.583333
# 73             0.458333
# 109            1.000000
# 48             0.041667
# 123            0.708333
# 92             0.458333
# 102            0.833333
# 11             0.041667
# 98             0.416667
# 126            0.708333
# 40             0.083333
# 133            0.583333
# 77             0.666667
# 24             0.041667
# 8              0.041667
# 20             0.041667
# 22             0.041667
# 93             0.375000
# 36             0.041667
# 68             0.583333
# 32             0.000000
# 141            0.916667
# 125            0.708333

# %% [markdown]
# ### Covariance and Correlation Matrix

# %%
df_train_features.cov()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.656249    -0.031723      1.206984     0.494679
# sepal_width      -0.031723     0.197907     -0.338052    -0.121731
# petal_length      1.206984    -0.338052      3.076178     1.299167
# petal_width       0.494679    -0.121731      1.299167     0.593205

# %%
df_train_features.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.088024      0.849497     0.792843
# sepal_width      -0.088024     1.000000     -0.433259    -0.355278
# petal_length      0.849497    -0.433259      1.000000     0.961738
# petal_width       0.792843    -0.355278      0.961738     1.000000

# %%
corr = df_train_features.corr()
corr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# C:\Users\Cursist\AppData\Local\Temp\ipykernel_11252\512550829.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# #T_e02f2_row0_col0, #T_e02f2_row1_col1, #T_e02f2_row2_col2, #T_e02f2_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e02f2_row0_col1, #T_e02f2_row1_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_e02f2_row0_col2, #T_e02f2_row2_col0 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_e02f2_row0_col3, #T_e02f2_row3_col0 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_e02f2_row1_col2, #T_e02f2_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e02f2_row1_col3, #T_e02f2_row3_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_e02f2_row2_col3, #T_e02f2_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e02f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e02f2_level0_col0" class="col_heading level0 col0" >sepal_length</th>
#       <th id="T_e02f2_level0_col1" class="col_heading level0 col1" >sepal_width</th>
#       <th id="T_e02f2_level0_col2" class="col_heading level0 col2" >petal_length</th>
#       <th id="T_e02f2_level0_col3" class="col_heading level0 col3" >petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e02f2_level0_row0" class="row_heading level0 row0" >sepal_length</th>
#       <td id="T_e02f2_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_e02f2_row0_col1" class="data row0 col1" >-0.09</td>
#       <td id="T_e02f2_row0_col2" class="data row0 col2" >0.85</td>
#       <td id="T_e02f2_row0_col3" class="data row0 col3" >0.79</td>
#     </tr>
#     <tr>
#       <th id="T_e02f2_level0_row1" class="row_heading level0 row1" >sepal_width</th>
#       <td id="T_e02f2_row1_col0" class="data row1 col0" >-0.09</td>
#       <td id="T_e02f2_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_e02f2_row1_col2" class="data row1 col2" >-0.43</td>
#       <td id="T_e02f2_row1_col3" class="data row1 col3" >-0.36</td>
#     </tr>
#     <tr>
#       <th id="T_e02f2_level0_row2" class="row_heading level0 row2" >petal_length</th>
#       <td id="T_e02f2_row2_col0" class="data row2 col0" >0.85</td>
#       <td id="T_e02f2_row2_col1" class="data row2 col1" >-0.43</td>
#       <td id="T_e02f2_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_e02f2_row2_col3" class="data row2 col3" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_e02f2_level0_row3" class="row_heading level0 row3" >petal_width</th>
#       <td id="T_e02f2_row3_col0" class="data row3 col0" >0.79</td>
#       <td id="T_e02f2_row3_col1" class="data row3 col1" >-0.36</td>
#       <td id="T_e02f2_row3_col2" class="data row3 col2" >0.96</td>
#       <td id="T_e02f2_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.matshow(corr, fignum=0)
plt.title('Correlation Matrix', fontsize=16, pad=80);
plt.xticks(range(df_train_features.shape[1]), 
           df_train_features.columns, 
           fontsize=12,
          rotation=60)
plt.yticks(range(df_train_features.shape[1]), 
           df_train_features.columns, 
           fontsize=12)
cb = plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.heatmap(corr, 
            mask = np.zeros_like(corr, dtype='bool'), 
            cmap = sns.diverging_palette(220, 10, as_cmap=True),
            square = True)
plt.show()

# %%
df_train_features
df_train_target
df_test_features
df_test_target

df_train.to_csv('../datasets/train_data.csv')
df_test.to_csv('../datasets/test_data.csv')

# %%
# !ls ../datasets
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Principle Component Analysis

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# ### 3 components

# %%
n_components = 3

pca3 = PCA(n_components = n_components)
pca3.fit(train_features_scaled)
# Out:
# PCA(n_components=3)

# %%
pca3.components_
# Out:
# array([[ 0.40552316, -0.15311488,  0.62253553,  0.65157986],
#        [ 0.44071728,  0.8949518 , -0.06945443,  0.00237457],
#        [-0.71829499,  0.34641568, -0.0736838 ,  0.59884821]])

# %%
train_features_pca3 = pca3.transform(train_features_scaled)
test_features_pca3 = pca3.transform(test_features_scaled)

# %%
df_train_features_pca3 = pd.DataFrame(train_features_pca3,
                                      columns = ['PCA%i_%i' % (n_components, i) for i in range(n_components)],
                                      index=df_train_features.index)
df_train_features_pca3
# Out:
#        PCA3_0    PCA3_1    PCA3_2
# 9   -0.667641 -0.072914 -0.054618
# 114  0.463711 -0.115438  0.250668
# 145  0.535916  0.068024  0.073739
# 135  0.745162  0.179668 -0.137221
# 140  0.599619  0.100623  0.108044
# ..        ...       ...       ...
# 143  0.609555  0.146463  0.073762
# 116  0.409842  0.039453 -0.014927
# 53   0.045108 -0.326529 -0.022142
# 38  -0.711902 -0.168921  0.058204
# 47  -0.691399 -0.071055  0.045896
#
# [105 rows x 3 columns]

# %%
df_test_features_pca3 = pd.DataFrame(test_features_pca3,
                                     columns = ['PCA%i_%i' % (n_components, i) for i in range(n_components)],
                                     index = df_test_features.index)
df_test_features_pca3
# Out:
#        PCA3_0    PCA3_1    PCA3_2
# 91   0.159586  0.000866 -0.023490
# 63   0.176700 -0.037621 -0.039195
# 103  0.404426 -0.023519  0.009274
# 6   -0.677009  0.003624  0.099716
# 59   0.002211 -0.212800  0.121674
# 29  -0.658668 -0.061207  0.023403
# 27  -0.632218  0.113070 -0.031788
# 35  -0.667808 -0.019691 -0.031374
# 99   0.046472 -0.116794  0.008852
# 122  0.740874  0.097607 -0.248567
# 82   0.015500 -0.139545 -0.047946
# 42  -0.724661 -0.094341  0.087072
# 117  0.731375  0.470702 -0.054323
# 61   0.121273 -0.018730  0.046449
# 43  -0.535417  0.087784  0.106655
# 79  -0.086616 -0.184485 -0.087249
# 100  0.611884  0.121543  0.236593
# 25  -0.612115 -0.099060 -0.065323
# 108  0.496470 -0.126104 -0.130813
# 94   0.052320 -0.167523  0.013100
# 74   0.140411  0.003796 -0.118923
# 54   0.244553 -0.024646 -0.107217
# 51   0.197036  0.113468 -0.028258
# 73   0.128781 -0.075109 -0.103533
# 109  0.704859  0.342393  0.099050
# 48  -0.633713  0.199891 -0.022873
# 123  0.342052 -0.089716 -0.010701
# 92   0.032613 -0.178032 -0.063650
# 102  0.601810  0.108413 -0.064868
# 11  -0.660163  0.025614  0.032318
# 98  -0.174341 -0.289141  0.049337
# 126  0.313674 -0.063471  0.024956
# 40  -0.649064  0.091079  0.035610
# 133  0.275691 -0.055118 -0.073664
# 77   0.351555  0.069826 -0.073432
# 24  -0.627963  0.022022  0.028507
# 8   -0.694789 -0.207408  0.042499
# 20  -0.581842  0.097869 -0.088668
# 22  -0.759852  0.082894  0.108714
# 93  -0.167795 -0.379654  0.011658
# 36  -0.619891  0.152191 -0.089105
# 68   0.238305 -0.283913 -0.132693
# 32  -0.697646  0.336709  0.029864
# 141  0.541332  0.130996  0.049538
# 125  0.529601  0.193740 -0.132079

# %%
corr = df_train_features_pca3.corr()
corr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(3)
# Out:
# C:\Users\Cursist\AppData\Local\Temp\ipykernel_11252\1389272493.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(3)
# <style type="text/css">
# #T_22aa4_row0_col0, #T_22aa4_row1_col1, #T_22aa4_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_22aa4_row0_col1, #T_22aa4_row0_col2, #T_22aa4_row1_col0, #T_22aa4_row1_col2, #T_22aa4_row2_col0, #T_22aa4_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_22aa4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22aa4_level0_col0" class="col_heading level0 col0" >PCA3_0</th>
#       <th id="T_22aa4_level0_col1" class="col_heading level0 col1" >PCA3_1</th>
#       <th id="T_22aa4_level0_col2" class="col_heading level0 col2" >PCA3_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22aa4_level0_row0" class="row_heading level0 row0" >PCA3_0</th>
#       <td id="T_22aa4_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_22aa4_row0_col1" class="data row0 col1" >-0.000</td>
#       <td id="T_22aa4_row0_col2" class="data row0 col2" >-0.000</td>
#     </tr>
#     <tr>
#       <th id="T_22aa4_level0_row1" class="row_heading level0 row1" >PCA3_1</th>
#       <td id="T_22aa4_row1_col0" class="data row1 col0" >-0.000</td>
#       <td id="T_22aa4_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_22aa4_row1_col2" class="data row1 col2" >-0.000</td>
#     </tr>
#     <tr>
#       <th id="T_22aa4_level0_row2" class="row_heading level0 row2" >PCA3_2</th>
#       <td id="T_22aa4_row2_col0" class="data row2 col0" >-0.000</td>
#       <td id="T_22aa4_row2_col1" class="data row2 col1" >-0.000</td>
#       <td id="T_22aa4_row2_col2" class="data row2 col2" >1.000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_pca3 = pd.concat([df_train_features_pca3, df_train_target], axis=1)
sns.pairplot(data = df_pca3, 
             vars = list(df_pca3.columns)[:-1], 
             hue = list(df_pca3.columns)[-1])
plt.show()

# %% [markdown]
# ## Save training and test datasets

# %%
df_train = pd.concat([df_train_features,
                      df_train_features_scaled,
                      df_train_features_pca3,
                      df_train_target], axis=1)
df_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  \
# 9             4.9          3.1           1.5          0.1
# 114           5.8          2.8           5.1          2.4
# 145           6.7          3.0           5.2          2.3
# 135           7.7          3.0           6.1          2.3
# 140           6.7          3.1           5.6          2.4
# ..            ...          ...           ...          ...
# 143           6.8          3.2           5.9          2.3
# 116           6.5          3.0           5.5          1.8
# 53            5.5          2.3           4.0          1.3
# 38            4.4          3.0           1.3          0.2
# 47            4.6          3.2           1.4          0.2
#
#      sepal_length_scaled  sepal_width_scaled  petal_length_scaled  \
# 9               0.166667            0.458333             0.068966
# 114             0.416667            0.333333             0.689655
# 145             0.666667            0.416667             0.706897
# 135             0.944444            0.416667             0.862069
# 140             0.666667            0.458333             0.775862
# ..                   ...                 ...                  ...
# 143             0.694444            0.500000             0.827586
# 116             0.611111            0.416667             0.758621
# 53              0.333333            0.125000             0.500000
# 38              0.027778            0.416667             0.034483
# 47              0.083333            0.500000             0.051724
#
#      petal_width_scaled    PCA3_0    PCA3_1    PCA3_2     species
# 9              0.000000 -0.667641 -0.072914 -0.054618      setosa
# 114            0.958333  0.463711 -0.115438  0.250668   virginica
# 145            0.916667  0.535916  0.068024  0.073739   virginica
# 135            0.916667  0.745162  0.179668 -0.137221   virginica
# 140            0.958333  0.599619  0.100623  0.108044   virginica
# ..                  ...       ...       ...       ...         ...
# 143            0.916667  0.609555  0.146463  0.073762   virginica
# 116            0.708333  0.409842  0.039453 -0.014927   virginica
# 53             0.500000  0.045108 -0.326529 -0.022142  versicolor
# 38             0.041667 -0.711902 -0.168921  0.058204      setosa
# 47             0.041667 -0.691399 -0.071055  0.045896      setosa
#
# [105 rows x 12 columns]

# %%
df_test = pd.concat([df_test_features,
                     df_test_features_scaled,
                     df_test_features_pca3,
                     df_test_target], axis=1)
df_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  \
# 91            6.1          3.0           4.6          1.4
# 63            6.1          2.9           4.7          1.4
# 103           6.3          2.9           5.6          1.8
# 6             4.6          3.4           1.4          0.3
# 59            5.2          2.7           3.9          1.4
# 29            4.7          3.2           1.6          0.2
# 27            5.2          3.5           1.5          0.2
# 35            5.0          3.2           1.2          0.2
# 99            5.7          2.8           4.1          1.3
# 122           7.7          2.8           6.7          2.0
# 82            5.8          2.7           3.9          1.2
# 42            4.4          3.2           1.3          0.2
# 117           7.7          3.8           6.7          2.2
# 61            5.9          3.0           4.2          1.5
# 43            5.0          3.5           1.6          0.6
# 79            5.7          2.6           3.5          1.0
# 100           6.3          3.3           6.0          2.5
# 25            5.0          3.0           1.6          0.2
# 108           6.7          2.5           5.8          1.8
# 94            5.6          2.7           4.2          1.3
# 74            6.4          2.9           4.3          1.3
# 54            6.5          2.8           4.6          1.5
# 51            6.4          3.2           4.5          1.5
# 73            6.1          2.8           4.7          1.2
# 109           7.2          3.6           6.1          2.5
# 48            5.3          3.7           1.5          0.2
# 123           6.3          2.7           4.9          1.8
# 92            5.8          2.6           4.0          1.2
# 102           7.1          3.0           5.9          2.1
# 11            4.8          3.4           1.6          0.2
# 98            5.1          2.5           3.0          1.1
# 126           6.2          2.8           4.8          1.8
# 40            5.0          3.5           1.3          0.3
# 133           6.3          2.8           5.1          1.5
# 77            6.7          3.0           5.0          1.7
# 24            4.8          3.4           1.9          0.2
# 8             4.4          2.9           1.4          0.2
# 20            5.4          3.4           1.7          0.2
# 22            4.6          3.6           1.0          0.2
# 93            5.0          2.3           3.3          1.0
# 36            5.5          3.5           1.3          0.2
# 68            6.2          2.2           4.5          1.5
# 32            5.2          4.1           1.5          0.1
# 141           6.9          3.1           5.1          2.3
# 125           7.2          3.2           6.0          1.8
#
#      sepal_length_scaled  sepal_width_scaled  petal_length_scaled  \
# 91              0.500000            0.416667             0.603448
# 63              0.500000            0.375000             0.620690
# 103             0.555556            0.375000             0.775862
# 6               0.083333            0.583333             0.051724
# 59              0.250000            0.291667             0.482759
# 29              0.111111            0.500000             0.086207
# 27              0.250000            0.625000             0.068966
# 35              0.194444            0.500000             0.017241
# 99              0.388889            0.333333             0.517241
# 122             0.944444            0.333333             0.965517
# 82              0.416667            0.291667             0.482759
# 42              0.027778            0.500000             0.034483
# 117             0.944444            0.750000             0.965517
# 61              0.444444            0.416667             0.534483
# 43              0.194444            0.625000             0.086207
# 79              0.388889            0.250000             0.413793
# 100             0.555556            0.541667             0.844828
# 25              0.194444            0.416667             0.086207
# 108             0.666667            0.208333             0.810345
# 94              0.361111            0.291667             0.534483
# 74              0.583333            0.375000             0.551724
# 54              0.611111            0.333333             0.603448
# 51              0.583333            0.500000             0.586207
# 73              0.500000            0.333333             0.620690
# 109             0.805556            0.666667             0.862069
# 48              0.277778            0.708333             0.068966
# 123             0.555556            0.291667             0.655172
# 92              0.416667            0.250000             0.500000
# 102             0.777778            0.416667             0.827586
# 11              0.138889            0.583333             0.086207
# 98              0.222222            0.208333             0.327586
# 126             0.527778            0.333333             0.637931
# 40              0.194444            0.625000             0.034483
# 133             0.555556            0.333333             0.689655
# 77              0.666667            0.416667             0.672414
# 24              0.138889            0.583333             0.137931
# 8               0.027778            0.375000             0.051724
# 20              0.305556            0.583333             0.103448
# 22              0.083333            0.666667            -0.017241
# 93              0.194444            0.125000             0.379310
# 36              0.333333            0.625000             0.034483
# 68              0.527778            0.083333             0.586207
# 32              0.250000            0.875000             0.068966
# 141             0.722222            0.458333             0.689655
# 125             0.805556            0.500000             0.844828
#
#      petal_width_scaled    PCA3_0    PCA3_1    PCA3_2     species
# 91             0.541667  0.159586  0.000866 -0.023490  versicolor
# 63             0.541667  0.176700 -0.037621 -0.039195  versicolor
# 103            0.708333  0.404426 -0.023519  0.009274   virginica
# 6              0.083333 -0.677009  0.003624  0.099716      setosa
# 59             0.541667  0.002211 -0.212800  0.121674  versicolor
# 29             0.041667 -0.658668 -0.061207  0.023403      setosa
# 27             0.041667 -0.632218  0.113070 -0.031788      setosa
# 35             0.041667 -0.667808 -0.019691 -0.031374      setosa
# 99             0.500000  0.046472 -0.116794  0.008852  versicolor
# 122            0.791667  0.740874  0.097607 -0.248567   virginica
# 82             0.458333  0.015500 -0.139545 -0.047946  versicolor
# 42             0.041667 -0.724661 -0.094341  0.087072      setosa
# 117            0.875000  0.731375  0.470702 -0.054323   virginica
# 61             0.583333  0.121273 -0.018730  0.046449  versicolor
# 43             0.208333 -0.535417  0.087784  0.106655      setosa
# 79             0.375000 -0.086616 -0.184485 -0.087249  versicolor
# 100            1.000000  0.611884  0.121543  0.236593   virginica
# 25             0.041667 -0.612115 -0.099060 -0.065323      setosa
# 108            0.708333  0.496470 -0.126104 -0.130813   virginica
# 94             0.500000  0.052320 -0.167523  0.013100  versicolor
# 74             0.500000  0.140411  0.003796 -0.118923  versicolor
# 54             0.583333  0.244553 -0.024646 -0.107217  versicolor
# 51             0.583333  0.197036  0.113468 -0.028258  versicolor
# 73             0.458333  0.128781 -0.075109 -0.103533  versicolor
# 109            1.000000  0.704859  0.342393  0.099050   virginica
# 48             0.041667 -0.633713  0.199891 -0.022873      setosa
# 123            0.708333  0.342052 -0.089716 -0.010701   virginica
# 92             0.458333  0.032613 -0.178032 -0.063650  versicolor
# 102            0.833333  0.601810  0.108413 -0.064868   virginica
# 11             0.041667 -0.660163  0.025614  0.032318      setosa
# 98             0.416667 -0.174341 -0.289141  0.049337  versicolor
# 126            0.708333  0.313674 -0.063471  0.024956   virginica
# 40             0.083333 -0.649064  0.091079  0.035610      setosa
# 133            0.583333  0.275691 -0.055118 -0.073664   virginica
# 77             0.666667  0.351555  0.069826 -0.073432  versicolor
# 24             0.041667 -0.627963  0.022022  0.028507      setosa
# 8              0.041667 -0.694789 -0.207408  0.042499      setosa
# 20             0.041667 -0.581842  0.097869 -0.088668      setosa
# 22             0.041667 -0.759852  0.082894  0.108714      setosa
# 93             0.375000 -0.167795 -0.379654  0.011658  versicolor
# 36             0.041667 -0.619891  0.152191 -0.089105      setosa
# 68             0.583333  0.238305 -0.283913 -0.132693  versicolor
# 32             0.000000 -0.697646  0.336709  0.029864      setosa
# 141            0.916667  0.541332  0.130996  0.049538   virginica
# 125            0.708333  0.529601  0.193740 -0.132079   virginica

# %%
df_train.to_csv('../datasets/iris_training_dataset.csv')
df_test.to_csv('../datasets/iris_test_dataset.csv')

# %%
import pickle
with open('../datasets/scaler.pickle', 'wb') as f:
    pickle.dump(scaler, f)
with open('../datasets/pca3.pickle', 'wb') as f:
    pickle.dump(pca3, f)
